# %%
import pickle
import os

import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap, BoundaryNorm
from matplotlib.collections import LineCollection
from functools import partial

from Gmodel import GProblem

# %% [markdown]
# # Visualising solutions
#
# The code creates sample solution landscapes similar to those reported by Grim et al. - not included in paper.

# %%
# Create sample solutions
solutions = []

for i in range(4):
    solution = []
    for s in [0, 5, 10, 20]:
        solution.append(GProblem(2000, 2, 2, 2, s).solution)
    solutions.append(solution)

# Set up chart
fig, ax = plt.subplots(nrows=4, ncols=1, figsize=(20, 20), sharex=True, sharey=True)
fig.suptitle(
    " First 200 points of sample landscapes, created with various smoothness factors."
)
ax[0].set_title("Smoothness 0")
ax[1].set_title("Smoothness 5")
ax[2].set_title("Smoothness 10")
ax[3].set_title("Smoothness 20")

# Plot solutions
for solution in solutions:
    ax[0].plot(range(0, 200), solution[0][:200], label="Smoothness 0")
    ax[1].plot(range(0, 200), solution[1][:200], label="Smoothness 5")
    ax[2].plot(range(0, 200), solution[2][:200], label="Smoothness 10")
    ax[3].plot(range(0, 200), solution[3][:200], label="Smoothness 20")

fig.savefig("Figure1.png", dpi = 300)
# Out:
# Drawing solution with 5
# Drawing solution with 10
# Drawing solution with 20
# Drawing solution with 5
# Drawing solution with 10
# Drawing solution with 20
# Drawing solution with 5
# Drawing solution with 10
# Drawing solution with 20
# Drawing solution with 5
# Drawing solution with 10
# Drawing solution with 20
# Drawing solution with 5
# Drawing solution with 10
# Drawing solution with 20

# %% [markdown]
# # Grim et al - replication runs - main
#
# 500 replication runs were conducted on GCE, using [pyscript2GCE](https://github.com/LukasWallrich/pyscript2gce-production). See `run_simulation_simple.py` for the code used. Note that this step only uses the relay-strategy as used by Hong & Page - so the strategy parameter of GProblem needs to be set to "relay" when conducting the simulation. Note that code to analyse the data when "both" strategies were used is available in the next section.

# %%
with open("Grimmodel_results.pkl", "rb") as f:
    res = pickle.load(f)

# %%
# Prepare dataframe (pivot and rename columns)
def prep_outputs(res):
    if "solution" in res.columns:
        res.rename({"solution": "best_solution"}, inplace=True)
        
    res = pd.concat(
        [
            res.drop(["best_solution"], axis=1),
            res.best_solution.apply(pd.Series).add_suffix("_solution"),
        ],
        axis=1,
    )

    def renamer(col, prefix):
        if col.endswith("agent"):
            return col
        else:
            return prefix + col

    res_random = (
        res.agent_descriptives.apply(pd.Series)
        .random.apply(pd.Series)
        .rename(mapper=partial(renamer, prefix="random_"), axis="columns")
    )

    res_best = (
        res.agent_descriptives.apply(pd.Series)
        .best.apply(pd.Series)
        .rename(mapper=partial(renamer, prefix="best_"), axis="columns")
    )

    res = pd.concat(
        [
            res.drop(["agent_descriptives"], axis=1),
            res_best,
            res_random[
                res_random.columns[
                    pd.Series(res_random.columns).str.startswith("random_")
                ]
            ],
        ],
        axis=1,
    )

    res["run_id"] = res.reset_index().index
    res = res.rename(columns={"best_agent": "top_agent"})
    res["gap"] = res["random_solution"] - res["best_solution"]
    return res

# %%
res = prep_outputs(res)

# %% [markdown]
# ## Reproducing Figure 2

# %%
# Calculate plot values (gap between random and best teams)
gaps = (
    res[["smoothness", "gap"]]
    .groupby(["smoothness"])
    .describe()
    .loc[:, (slice(None), ["mean", "std"])]
)
gaps.columns = gaps.columns.droplevel(0)
gaps.reset_index(inplace=True)

# Set up plot
fig, ax = plt.subplots()

tickpos = range(0, 21, 2)

# Plot separate lines depending on which team performs best
(rand_better,) = ax.plot(
    gaps["smoothness"][gaps["mean"] >= 0],
    gaps["mean"][gaps["mean"] >= 0],
    "tab:blue",
    label="random groups perform better",
)
(best_better,) = ax.plot(
    gaps["smoothness"][gaps["mean"] <= 0],
    gaps["mean"][gaps["mean"] <= 0],
    "tab:red",
    label="groups of highest-ability agents perform better",
)
ax.plot(gaps["smoothness"][3:5], gaps["mean"][3:5], "tab:grey")

ax.fill_between(
    gaps["smoothness"],
    gaps["mean"] - gaps["std"],
    gaps["mean"] + gaps["std"],
    alpha=0.35,
)
ax.axhline(y=0, color="grey", linestyle="--")
ax.set_xticks(tickpos)
ax.set_ylabel("Difference in average scores")
ax.set_xlabel("Smoothness of solution landscape")

ax.legend(handles=[rand_better, best_better])

ax.annotate(
    "Shaded region \n is +/- 1 SD",
    xy=(10, 0.01),
    xycoords="data",
    xytext=(50, 30),
    textcoords="offset points",
    arrowprops=dict(arrowstyle="->"),
    horizontalalignment="right",
    verticalalignment="bottom",
)

fig.figure.savefig("Fig2.png", dpi = 300)
fig.figure.savefig("../manuscript/Fig2.png", dpi = 300)

# %% [markdown]
# Supplementary - the following replicates the table from Hong & Page. Key insight: overall performance declines with higher smoothness.

# %%
# Pivot so that random and best groups can be easily compared

# Function to identify columns to be pivoted
def check_var(col_name):
    return not (col_name.find("random_") != -1 or col_name.find("best_") != -1)

col_names = res.columns.values.tolist()
id_cols = list(filter(check_var, col_names))

# Pivot longer, then wider
out = pd.melt(res, id_cols)

out = (
    out.join(out.variable.str.split("_", expand=True))
    .rename(columns={0: "team_type"})
    .pivot_table(index=id_cols + ["team_type"], columns=[1], values="value")
    .reset_index()
)

out["NPdiversity"] = out["NPdiversity"] * 100  # Convert to percentages

# %%
# Summarise performance and diversity of best versus random teams,
# depending on smoothness of landscape
tbl = (
    out[["team_type", "smoothness", "solution", "NPdiversity"]]
    .groupby(["smoothness", "team_type"])
    .describe()
    .loc[:, (slice(None), ["mean", "std"])]
)

tbl = tbl.round(2)

sol = pd.DataFrame(
    tbl[("solution", "mean")].astype(str)
    + " ("
    + tbl[("solution", "std")].astype(str)
    + ")"
)
sol.columns = ["Solution"]

div = pd.DataFrame(
    tbl[("NPdiversity", "mean")].astype(str)
    + " ("
    + tbl[("NPdiversity", "std")].astype(str)
    + ")"
)
div.columns = ["Diversity"]

sol = sol.join(div)

sol
# Out:
#                           Solution     Diversity
# smoothness team_type
# 0          best        92.4 (1.28)  84.66 (4.15)
#            random     94.35 (0.58)  91.54 (2.31)
# 1          best       89.31 (1.22)  77.04 (4.58)
#            random      91.49 (0.8)  91.65 (2.35)
# 2          best       85.43 (1.26)  76.56 (3.94)
#            random     86.68 (1.17)   91.8 (2.45)
# 3          best        82.4 (1.25)  76.15 (3.04)
#            random     82.74 (1.45)   91.84 (2.3)
# 4          best        80.0 (1.39)  73.41 (3.57)
#            random     79.82 (1.54)  91.63 (2.35)
# 5          best       77.89 (1.65)  70.71 (4.29)
#            random      77.5 (1.75)  91.73 (2.21)
# 6          best       75.81 (1.78)   68.3 (5.26)
#            random     75.34 (1.91)  91.71 (2.43)
# 7          best       74.41 (1.86)   67.1 (5.71)
#            random     73.94 (1.96)  91.65 (2.33)
# 8          best       73.13 (2.03)  66.37 (6.42)
#            random     72.69 (2.11)  91.89 (2.33)
# ...

# %% [markdown]
# # Replication of tournament results
#
# The comparisons between best and random groups under tournament setting was only tested with 100 runs but with l ranging up to 30. This already increased computational expense >5x compared to the range considered in the original paper.

# %%
# Load and merge results (were run in several segments)
res = []

for file in os.listdir("."):
    filename = os.fsdecode(file)
    if filename.startswith("GrimSweepTournament"):  
        # Multiple files from use of spot VMs
        with open(filename, "rb") as f:
            res.append(pickle.load(f))
        continue
    else:
        continue

res = pd.concat(res)

# %%
# Pivot so that random and best groups, and the two strategies, can be easily compared
## Beware: this cell is very slow (~90 seconds)

# Function to add prefix to columns that describe teams (not individual agents)
def renamer(col, prefix):
    if col.endswith("agent"):
        return col
    else:
        return prefix + col

# Extract different results to then merge
res = pd.concat(
    [
        res.drop(["best_solution"], axis=1),
        res.best_solution.apply(pd.Series).add_suffix("_solution"),
    ],
    axis=1,
)
res_random = (
    res.agent_descriptives.apply(pd.Series)
    .random.apply(pd.Series)
    .rename(mapper=partial(renamer, prefix="random_"), axis="columns")
)
res_best = (
    res.agent_descriptives.apply(pd.Series)
    .best.apply(pd.Series)
    .rename(mapper=partial(renamer, prefix="best_"), axis="columns")
)
res = pd.concat(
    [
        res.drop(["agent_descriptives"], axis=1),
        res_best,
        res_random[
            res_random.columns[pd.Series(res_random.columns).str.startswith("random_")]
        ],
    ],
    axis=1,
)
res["run_id"] = res.reset_index().index
res.rename(columns={"best_agent": "top_agent"}, inplace=True)

# Calculate performance differences for each strategy
res["tournament_gap"] = res["tournament_random_solution"] - res["tournament_best_solution"]
res["relay_gap"] = res["relay_random_solution"] - res["relay_best_solution"]
# Out:
#        smoothness   l   Run     n  k  N_agents strategy  \
# 0               0   4  2000  2000  3        10     both
# 7555           14   4  2000  2000  3        10     both
# 7556           14   4  2000  2000  3        10     both
# 7557           14   4  2000  2000  3        10     both
# 7558           14   4  2000  2000  3        10     both
# ...           ...  ..   ...   ... ..       ...      ...
# 7556            7   4  2000  2000  3        10     both
# 7555            7   4  2000  2000  3        10     both
# 7554            7   4  2000  2000  3        10     both
# 7530            6  30  2000  2000  3        10     both
# 22679          20  30  2000  2000  3        10     both
#
#        relay_random_solution  relay_best_solution  tournament_best_solution  \
# 0                  87.130439            87.067030                 89.639316
# 7555               65.320451            65.268111                 65.643081
# ...

# %%
# Summarise results

## Summarise by max step size and smoothness
comps = res.groupby(["l", "smoothness"]).apply(
    lambda s: pd.Series(
        {
            "tournament_random_advantage": s["tournament_gap"].mean(),
            "relay_random_advantage": s["relay_gap"].mean(),
            "tournament_advantage_random": (
                s["tournament_random_solution"] - s["relay_random_solution"]
            ).mean(),
            "tournament_advantage_best": (
                s["tournament_best_solution"] - s["relay_best_solution"]
            ).mean(),
        }
    )
)

## Aggregate and create table
win_comps = pd.DataFrame(
    [
        {
            "Strategy": "Relay",
            "Win rate (%)": round((comps["relay_random_advantage"] > 0).mean(), 3)
            * 100,
            "Mean advantage": round(comps["relay_random_advantage"].mean(), 2),
            "random_mean": round(
                comps["relay_random_advantage"][
                    comps["relay_random_advantage"] > 0
                ].mean(),
                2,
            ),
            "random_max": round(
                comps["relay_random_advantage"][
                    comps["relay_random_advantage"] > 0
                ].max(),
                2,
            ),
            "best_mean": round(
                abs(
                    comps["relay_random_advantage"][
                        comps["relay_random_advantage"] < 0
                    ].mean()
                ),
                2,
            ),
            "best_max": round(
                abs(
                    comps["relay_random_advantage"][
                        comps["relay_random_advantage"] < 0
                    ].min()
                ),
                2,
            ),
        },
        {
            "Strategy": "Tournament",
            "Win rate (%)": round((comps["tournament_random_advantage"] > 0).mean(), 3)
            * 100,
            "Mean advantage": round(comps["tournament_random_advantage"].mean(), 2),
            "random_mean": round(
                comps["tournament_random_advantage"][
                    comps["tournament_random_advantage"] > 0
                ].mean(),
                2,
            ),
            "random_max": round(
                comps["tournament_random_advantage"][
                    comps["tournament_random_advantage"] > 0
                ].max(),
                2,
            ),
            "best_mean": round(
                abs(
                    comps["tournament_random_advantage"][
                        comps["tournament_random_advantage"] < 0
                    ].mean()
                ),
                2,
            ),
            "best_max": round(
                abs(
                    comps["tournament_random_advantage"][
                        comps["tournament_random_advantage"] < 0
                    ].min()
                ),
                2,
            ),
        },
    ]
)


win_comps.to_latex("win_comparisons.tex")

win_comps
# Out:
#      Strategy  Win rate (%)  Mean advantage  random_mean  random_max  \
# 0       Relay          25.9            0.14         1.50        3.32
# 1  Tournament          60.0            0.54         0.93        2.58
#
#    best_mean  best_max
# 0       0.34      0.69
# 1       0.06      0.21

# %%
# Plot relative performance heatmap
sns.set_theme()

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(8, 2.8))
cbar_ax = fig.add_axes([0.95, 0.2, 0.02, 0.6])

relay = (
    comps[["relay_random_advantage"]]
    .reset_index()
    .pivot("l", "smoothness", "relay_random_advantage")
)
# Overlay '-' on all boxes with negative values
relay_neg = (relay >= 0).replace([True, False], ["", "-"])
cmap = sns.diverging_palette(150, 275, s=80, l=55, as_cmap=True)
sns.heatmap(
    relay,
    cmap=cmap,
    center=0,
    annot=relay_neg,
    fmt="",
    ax=ax1,
    vmin=-0.7,
    vmax=3.4,
    cbar_ax=cbar_ax,
)
ax1.invert_yaxis()
ax1.plot([2, 9], [0, 27])
ax1.set_title("A. Relay mode", fontweight="bold")
ax1.set_ylabel("Max step length (l)", fontweight="bold")
ax1.set_xlabel("Smoothness", fontweight="bold")

tourn = (
    comps[["tournament_random_advantage"]]
    .reset_index()
    .pivot("l", "smoothness", "tournament_random_advantage")
)
tourn_neg = (tourn >= 0).replace([True, False], ["", "-"])
sns.heatmap(
    tourn,
    cmap=cmap,
    center=0,
    annot=tourn_neg,
    fmt="",
    ax=ax2,
    vmin=-0.7,
    vmax=3.4,
    cbar_ax=cbar_ax,
)
ax2.invert_yaxis()
ax2.plot([2, 10], [0, 16])
ax2.plot([10, 16], [16, 28], linestyle="dashed")
ax2.set_title("B. Tournament mode", fontweight="bold")
ax2.set_ylabel("Max step length (l)", fontweight="bold")
ax2.set_xlabel("Smoothness", fontweight="bold")

fig.figure.savefig("Fig69.png", dpi = 300)
fig.figure.savefig("../manuscript/Fig69.png", bbox_inches="tight", dpi = 300)

# %%
# Tournaments vs relays

# %%
# Compare how often tournament strategy wins over relay strategy on same solution,
# depending on team type
pd.DataFrame(
    [
        {
            "Group": "Random",
            "Tournament wins (%)": round(
                (comps["tournament_advantage_random"] > 0).mean(), 3
            )
            * 100,
            "Mean advantage": round(comps["tournament_advantage_random"].mean(), 2),
        },
        {
            "Group": "Best",
            "Tournament wins (%)": round(
                (comps["tournament_advantage_best"] > 0).mean(), 3
            )
            * 100,
            "Mean advantage": round(comps["tournament_advantage_best"].mean(), 2),
        },
    ]
)
# Out:
#     Group  Tournament wins (%)  Mean advantage
# 0  Random                100.0            2.68
# 1    Best                100.0            2.28
